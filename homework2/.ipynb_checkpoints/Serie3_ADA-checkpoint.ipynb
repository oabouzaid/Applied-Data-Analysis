# %%
# Import libraries
import requests
import pandas as pd
pd.options.mode.chained_assignment = None #Mute warnings
import numpy as np
from bs4 import BeautifulSoup
import sys
import matplotlib.pyplot as plt

# %%
URL = 'https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051.txt'
r = requests.get(URL).json()['data']
df = pd.DataFrame(r)
df.head()
# Out:
#    cc core_id         country  \
# 0  US     410   United States
# 1  US     573   United States
# 2  US     253   United States
# 3  US      94   United States
# 4  GB      95  United Kingdom
#
#                                                guide  \
# 0  <a href="/where-to-study/north-america/united-...
# 1  <a href="/where-to-study/north-america/united-...
# 2  <a href="/where-to-study/north-america/united-...
# 3  <a href="/where-to-study/north-america/united-...
# 4  <a href="/where-to-study/europe/united-kingdom...
#
#                                                 logo     nid rank_display  \
# 0  <img src="https://www.topuniversities.com/site...  294850            1
# 1  <img src="https://www.topuniversities.com/site...  297282            2
# 2  <img src="https://www.topuniversities.com/site...  294270            3
# 3  <img src="https://www.topuniversities.com/site...  294562            4
# 4  <img src="https://www.topuniversities.com/site...  294561            5
#
#           region score stars                                         title  \
# 0  North America   100     6   Massachusetts Institute of Technology (MIT)
# 1  North America  98.7     5                           Stanford University
# 2  North America  98.4     5                            Harvard University
# 3  North America  97.7     5  California Institute of Technology (Caltech)
# 4         Europe  95.6     5                       University of Cambridge
#
#                                                  url
# 0  /universities/massachusetts-institute-technolo...
# 1                  /universities/stanford-university
# 2                   /universities/harvard-university
# 3  /universities/california-institute-technology-...
# 4                 /universities/university-cambridge

# %%
df_crop = df[['country','rank_display', 'region','title']][:200]
df_crop.head()
# Out:
#           country rank_display         region  \
# 0   United States            1  North America
# 1   United States            2  North America
# 2   United States            3  North America
# 3   United States            4  North America
# 4  United Kingdom            5         Europe
#
#                                           title
# 0   Massachusetts Institute of Technology (MIT)
# 1                           Stanford University
# 2                            Harvard University
# 3  California Institute of Technology (Caltech)
# 4                       University of Cambridge

# %% [markdown]
# #### Now for each university, we have to find the # of faculty members, students and international students.
# For this, we will need the URLs of the respective unis.

# %%
suffixes = np.array(df['url'])
urls = []
for suffix in suffixes:
    urls.append('https://www.topuniversities.com' + suffix + '#wurs')

# %%
def find_number(soup, tag, my_class):
    try:
        soup.find(tag, class_= my_class).find(tag, class_='number') 
    except: 
        return 0
    
    return int(soup.find(tag, class_= my_class).find(tag, class_='number').text.strip('\n').replace(',','').strip(' '))

# %%
staff = []
int_staff = []
students = []
intl_students = []
i = 1

for url in urls[:200]:
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
   
    faculty_staff = find_number(soup,'div','faculty-main wrapper col-md-4')
    intl_faculty_staff = find_number(soup, 'div', 'inter faculty')
    students_ = find_number(soup, 'div', 'students-main wrapper col-md-4')
    int_students = find_number(soup, 'div','int-students-main wrapper col-md-4')
    
    staff.append(faculty_staff)
    int_staff.append(intl_faculty_staff)
    students.append(students_)
    intl_students.append(int_students)

# %%
staff_s = pd.Series(staff)
int_staff_s = pd.Series(int_staff)
students_s = pd.Series(students)
intl_students_s = pd.Series(intl_students)

# %%
df_crop['students'] = students_s
df_crop['intl_students'] = intl_students_s
df_crop['staff'] = staff_s
df_crop['intl_staff'] = int_staff_s

df_a = df_crop.copy()
df_a['students:staff ratio'] = students_s.divide(staff_s).round(3)
df_a['ratio intl students'] = (intl_students_s.divide(students_s).round(5))*100

# %%
# a. Ranking by student:staff ratio
df_a.sort_values(['ratio intl students'], ascending = False, inplace = True)
df_a.set_index(pd.Series(list(range(1,201))), inplace = True)
del df_a['rank_display']
df_a.head()
# Out:
#           country         region  \
# 1  United Kingdom         Europe
# 2     Switzerland         Europe
# 3  United Kingdom         Europe
# 4     Netherlands         Europe
# 5   United States  North America
#
#                                                title  students  intl_students  \
# 1  London School of Economics and Political Scien...      9760           6748
# 2    Ecole Polytechnique Fédérale de Lausanne (EPFL)     10343           5896
# 3                            Imperial College London     16090           8746
# 4                              Maastricht University     16385           8234
# 5                         Carnegie Mellon University     13356           6385
#
#    staff  intl_staff  students:staff ratio  ratio intl students
# 1   1088         687                 8.971               69.139
# 2   1695        1300                 6.102               57.005
# 3   3930        2071                 4.094               54.357
# 4   1277         502                12.831               50.253
# 5   1342         425                 9.952               47.806

# %%
# b. Ratio of international students
df_a.sort_values(['students:staff ratio'], ascending = True, inplace = True)
df_a = df_a.set_index(pd.Series(list(range(1,201))))
df_a.head()
# Out:
#           country         region  \
# 1   United States  North America
# 2   United States  North America
# 3  United Kingdom         Europe
# 4  United Kingdom         Europe
# 5   United States  North America
#
#                                           title  students  intl_students  \
# 1  California Institute of Technology (Caltech)      2255            647
# 2                               Yale University     12402           2469
# 3                          University of Oxford     19720           7353
# 4                       University of Cambridge     18770           6699
# 5                      Johns Hopkins University     16146           4105
#
#    staff  intl_staff  students:staff ratio  ratio intl students
# 1    953         350                 2.366               28.692
# 2   4940        1708                 2.511               19.908
# 3   6750        2964                 2.921               37.287
# 4   5490        2278                 3.419               35.690
# 5   4462        1061                 3.619               25.424

# %%
# c. Aggregating by country
df_c = df_crop.copy()
df_c = df_c.groupby('country').sum()
df_c['students:staff ratio'] = df_c['students'].divide(df_c['staff']).round(3)
df_c['ratio intl students'] = (df_c['intl_students'].divide(df_c['students']).round(5))*100
df_c
# Out:
#                 students  intl_students   staff  intl_staff  \
# country
# Argentina         122301          27109   16421        3165
# Australia         301994         106359   22034       11382
# Austria            63446          19667    4117        1572
# Belgium           115067          17013    8046        2187
# Brazil             92283           3052    7550         388
# Canada            281514          73239   29317       10734
# Chile              65851           3125    4516         325
# China             235898          26833   27220        6720
# Denmark            67223           9543   11916        3904
# Finland            34566           3065    3902         905
# France             35235           6864    4011         815
# Germany           342499          56455   33426        6402
# Hong Kong          78838          24499   10166        6296
# India              20950            220    1765          23
# New Zealand                   14.541               25.822
# Ireland                       12.196               23.530
# Netherlands                    9.742               23.298
# Argentina                      7.448               22.166
# France                         8.785               19.481
# Malaysia                       6.498               19.417
# United States                  8.277               17.305
# Sweden                        10.006               17.072
# South Africa                  11.306               16.970
# Russia                         4.506               16.862
# Germany                       10.246               16.483
# Saudi Arabia                   5.687               16.374
# Belgium                       14.301               14.785
# Denmark                        5.641               14.196
# Norway                         8.696               12.678
# Spain                         11.891               12.400
# South Korea                    7.056               11.618
# China                          8.666               11.375
# Italy                         21.512                9.873
# Taiwan                        12.042                9.415
# Finland                        8.859                8.867
# Japan                          6.558                8.736
# Israel                         7.350                6.255
# Chile                         14.582                4.746
# Brazil                        12.223                3.307
# Mexico                         9.193                2.308
# India                         11.870                1.050

# %%
# d. Aggregating by region
df_d = df_crop.copy()
df_d = df_d.groupby('region').sum()
df_d['students:staff ratio'] = df_d['students'].divide(df_d['staff']).round(3)
df_d['ratio intl students'] = (df_d['intl_students'].divide(df_d['students']).round(5))*100
df_d
# Out:
#                students  intl_students   staff  intl_staff  \
# region
# Africa            19593           3325    1733         379
# Asia             807003         110100  106734       25462
# Europe          1957251         449364  218358       67598
# Latin America    435750          36871   45382        5648
# North America   1546353         292116  182123       43836
# Oceania          350167         118798   25347       12786
#
#                students:staff ratio  ratio intl students
# region
# Africa                       11.306               16.970
# Asia                          7.561               13.643
# Europe                        8.963               22.959
# Latin America                 9.602                8.462
# North America                 8.491               18.891
# Oceania                      13.815               33.926

# %%
# Ranking by increasing ratio between faculty members and students (best first), by country
df_d.sort_values('students:staff ratio', ascending = True, inplace = True)
df_d
# Out:
#                students  intl_students   staff  intl_staff  \
# region
# Asia             807003         110100  106734       25462
# North America   1546353         292116  182123       43836
# Europe          1957251         449364  218358       67598
# Latin America    435750          36871   45382        5648
# Africa            19593           3325    1733         379
# Oceania          350167         118798   25347       12786
#
#                students:staff ratio  ratio intl students
# region
# Asia                          7.561               13.643
# North America                 8.491               18.891
# Europe                        8.963               22.959
# Latin America                 9.602                8.462
# Africa                       11.306               16.970
# Oceania                      13.815               33.926

# %%
df_d[['students','staff']].plot.bar(figsize=(10,6),title ='Ratio between faculty members and students by region')
plt.xlabel('Regions')
plt.ylabel('Number of students')
plt.show()

# %%
# Ranking by descreasing ratio of international students, by country
df_d.sort_values('ratio intl students', ascending = False)
# Out:
#                students  intl_students   staff  intl_staff  \
# region
# Oceania          350167         118798   25347       12786
# Europe          1957251         449364  218358       67598
# North America   1546353         292116  182123       43836
# Africa            19593           3325    1733         379
# Asia             807003         110100  106734       25462
# Latin America    435750          36871   45382        5648
#
#                students:staff ratio  ratio intl students
# region
# Oceania                      13.815               33.926
# Europe                        8.963               22.959
# North America                 8.491               18.891
# Africa                       11.306               16.970
# Asia                          7.561               13.643
# Latin America                 9.602                8.462
